# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
matches = pd.read_csv("Desktop/matches.csv")
deliveries = pd.read_csv("Desktop/deliveries.csv")

matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
matches.loc[matches['win_by_runs'].idxmax()]
# Out:
# id                               44
# season                         2017
# city                          Delhi
# date                     2017-05-06
# team1                Mumbai Indians
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision                 field
# result                       normal
# dl_applied                        0
# winner               Mumbai Indians
# win_by_runs                     146
# win_by_wickets                    0
# player_of_match         LMP Simmons
# venue              Feroz Shah Kotla
# umpire1                 Nitin Menon
# umpire2                   CK Nandan
# umpire3                         NaN
# Name: 43, dtype: object

# %% [markdown]
# **Insight**
# The match had the largest run difference in IPL. Mumbai Indians completely dominate the opponent with there batting line up

# %%
matches.loc[matches['win_by_wickets'].idxmax()]
# Out:
# id                                                      3
# season                                               2017
# city                                               Rajkot
# date                                           2017-04-07
# team1                                       Gujarat Lions
# team2                               Kolkata Knight Riders
# toss_winner                         Kolkata Knight Riders
# toss_decision                                       field
# result                                             normal
# dl_applied                                              0
# winner                              Kolkata Knight Riders
# win_by_runs                                             0
# win_by_wickets                                         10
# player_of_match                                   CA Lynn
# venue              Saurashtra Cricket Association Stadium
# umpire1                                       Nitin Menon
# ...

# %% [markdown]
# **Insight**
# In this match the chasing team reached the target  very easily with 10 wickets. It showing a very comfortable victory

# %%
matches[matches['win_by_runs']>0].sort_values('win_by_runs').head(1)
# Out:
#         id  season       city      date           team1                team2  \
# 755  11415    2019  Hyderabad  12/05/19  Mumbai Indians  Chennai Super Kings
#
#         toss_winner toss_decision  result  dl_applied          winner  \
# 755  Mumbai Indians           bat  normal           0  Mumbai Indians
#
#      win_by_runs  win_by_wickets player_of_match  \
# 755            1               0       JJ Bumrah
#
#                                   venue      umpire1    umpire2      umpire3
# 755  Rajiv Gandhi Intl. Cricket Stadium  Nitin Menon  Ian Gould  Nigel Llong

# %% [markdown]
# **Insight**
# This was a very close match where the MI won by 1 run. It shows how competetive the game was

# %%
matches[matches['win_by_wickets']>0].sort_values('win_by_wickets').head(1)
# Out:
#        id  season       city      date           team1                team2  \
# 642  7900    2018  Hyderabad  12/04/18  Mumbai Indians  Sunrisers Hyderabad
#
#              toss_winner toss_decision  result  dl_applied  \
# 642  Sunrisers Hyderabad         field  normal           0
#
#                   winner  win_by_runs  win_by_wickets player_of_match  \
# 642  Sunrisers Hyderabad            0               1     Rashid Khan
#
#                                          venue   umpire1      umpire2  \
# 642  Rajiv Gandhi International Stadium, Uppal  O Nandan  Nigel Llong
#
#              umpire3
# 642  Vineet Kulkarni

# %% [markdown]
# **Insight**
# This match was also very close because the chasing team won by 1 wicket

# %%
matches[matches['dl_applied']==1]
# Out:
#        id  season           city        date                        team1  \
# 56     57    2017      Bangalore  2017-05-17          Sunrisers Hyderabad
# 99    100    2008          Delhi  2008-05-17             Delhi Daredevils
# 102   103    2008        Kolkata  2008-05-18        Kolkata Knight Riders
# 119   120    2009      Cape Town  2009-04-19              Kings XI Punjab
# 122   123    2009         Durban  2009-04-21              Kings XI Punjab
# 148   149    2009      Centurion  2009-05-07          Chennai Super Kings
# 251   252    2011          Kochi  2011-04-18          Chennai Super Kings
# 280   281    2011        Kolkata  2011-05-07          Chennai Super Kings
# 290   291    2011      Bangalore  2011-05-14        Kolkata Knight Riders
# 488   489    2014          Delhi  2014-05-10             Delhi Daredevils
# 536   537    2015  Visakhapatnam  2015-04-22          Sunrisers Hyderabad
# 567   568    2015      Hyderabad  2015-05-15          Sunrisers Hyderabad
# ...

# %% [markdown]
# **Insight**
# The D/L method was used in matches that were affected by rain to calculate a fair target for the teams

# %%
matches['city'].value_counts()
# Out:
# city
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cuttack             7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Abu Dhabi           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
matches['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %% [markdown]
# **Insight**
# Teams with the higests number of wins have performed more consistently and successffully in IPL matches

# %%
matches['season'].value_counts().sort_index()
# Out:
# season
# 2008    58
# 2009    57
# 2010    60
# 2011    73
# 2012    74
# 2013    76
# 2014    60
# 2015    59
# 2016    60
# 2017    59
# 2018    60
# 2019    60
# Name: count, dtype: int64

# %% [markdown]
# The number of matches changes every season depending on the number of teams and tournament format

# %%
matches['player_of_match'].value_counts().head(10)
# Out:
# player_of_match
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
# YK Pathan         16
# SR Watson         15
# SK Raina          14
# G Gambhir         13
# MEK Hussey        12
# Name: count, dtype: int64

# %% [markdown]
# **Insight**
#
# These players have won the most Man of the Match awards because of their outstanding performances in many IPL games.

# %%
(matches['toss_winner']==matches['winner']).value_counts()
# Out:
# True     393
# False    363
# Name: count, dtype: int64

# %% [markdown]
# **Insight**
# Winning the toss does not always guarantee victory because the final result mainly depends on the team’s performance. But winning the toss give small advantage acccording your planning

# %%
matches['toss_decision'].value_counts()
# Out:
# toss_decision
# field    463
# bat      293
# Name: count, dtype: int64

# %% [markdown]
# **Insight**
#
# Most captains prefer to field first after winning the toss because chasing a target is often easier in T20 cricket

# %%
matches.groupby('season')['dl_applied'].sum()
# Out:
# season
# 2008    2
# 2009    3
# 2010    0
# 2011    3
# 2012    0
# 2013    0
# 2014    1
# 2015    2
# 2016    4
# 2017    1
# 2018    3
# 2019    0
# Name: dl_applied, dtype: int64

# %%
matches['result'].value_counts()
# Out:
# result
# normal       743
# tie            9
# no result      4
# Name: count, dtype: int64

# %%
matches['toss_winner'].value_counts()
# Out:
# toss_winner
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Royal Challengers Bangalore    81
# Kings XI Punjab                81
# Delhi Daredevils               80
# Rajasthan Royals               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: count, dtype: int64

# %%
matches[matches['win_by_wickets']>0]['venue'].value_counts().head(5)
# Out:
# venue
# Eden Gardens              45
# M Chinnaswamy Stadium     40
# Wankhede Stadium          37
# Feroz Shah Kotla          33
# Sawai Mansingh Stadium    32
# Name: count, dtype: int64

# %%
matches[matches['win_by_runs']>0]['winner'].value_counts().head(5)
# Out:
# winner
# Mumbai Indians                 57
# Chennai Super Kings            52
# Kings XI Punjab                38
# Kolkata Knight Riders          36
# Royal Challengers Bangalore    35
# Name: count, dtype: int64

# %%
matches['venue'].value_counts()
# Out:
# venue
# Eden Gardens                                            77
# M Chinnaswamy Stadium                                   73
# Wankhede Stadium                                        73
# Feroz Shah Kotla                                        67
# Rajiv Gandhi International Stadium, Uppal               56
# MA Chidambaram Stadium, Chepauk                         49
# Sawai Mansingh Stadium                                  47
# Punjab Cricket Association Stadium, Mohali              35
# Maharashtra Cricket Association Stadium                 21
# Subrata Roy Sahara Stadium                              17
# Dr DY Patil Sports Academy                              17
# Kingsmead                                               15
# Punjab Cricket Association IS Bindra Stadium, Mohali    14
# SuperSport Park                                         12
# Sardar Patel Stadium, Motera                            12
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     11
# ...

# %%
matches['venue'].value_counts().head(10).plot(kind='bar', figsize=(10,5))
plt.title("Top 10 Stadiums by Number of Matches")
plt.xlabel("Stadium")
plt.ylabel("Number of Matches")
plt.show()
